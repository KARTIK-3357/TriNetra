# %%
import numpy as np 
import pandas as pd

# %%
df1 = pd.read_csv("C:\TriNetra\data\Works Sanctioned.csv")
df2 = pd.read_csv("C:\TriNetra\data\Works Recommended (3).csv")
df3 = pd.read_csv("C:\TriNetra\data\Works Sanctioned.csv")
df4 = pd.read_csv("C:\TriNetra\data\Works Sanctioned.csv")
df5 = pd.read_csv("C:\TriNetra\data\Works Sanctioned.csv")
df6 = pd.read_csv("C:\TriNetra\data\Works Sanctioned.csv")
df7 = pd.read_csv("C:\TriNetra\data\Works Sanctioned.csv")
df8 = pd.read_csv("C:\TriNetra\data\Works Sanctioned.csv")
df9 = pd.read_csv("C:\TriNetra\data\Works Sanctioned.csv")
df10 = pd.read_csv("C:\TriNetra\data\Works Sanctioned.csv")
df11 = pd.read_csv("C:\TriNetra\data\Works Sanctioned.csv")
df12 = pd.read_csv("C:\TriNetra\data\Works Sanctioned.csv")
# Out:
# C:\Users\karti\AppData\Local\Temp\ipykernel_8496\1102335569.py:1: DtypeWarning: Columns (0: Sr. No., 1: Sanction Amount ( ₹ )) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv("C:\TriNetra\data\Works Sanctioned.csv")
