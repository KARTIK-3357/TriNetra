# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 

df = pd.read_csv("C:\TriNetra\data\mplads_data.csv")
df1 = pd.read_csv("C:\TriNetra\data\Works Sanctioned.csv")
df.columns
df1.columns
# Out:
# C:\Users\karti\AppData\Local\Temp\ipykernel_22876\511593403.py:6: DtypeWarning: Columns (0: Sr. No., 1: Sanction Amount ( ₹ )) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv("C:\TriNetra\data\Works Sanctioned.csv")
# Index(['Sr. No.', 'Work category', 'Work', 'State', 'IDA',
#        'Hon'ble Members of Parliament', 'Constituency', 'Work description',
#        'Recommended date', 'Sanction Date', 'Sanction Amount ( ₹ )',
#        'Work Status'],
#       dtype='str')

# %%
df.isna().sum()
# Out:
# project_id                0
# work_name                 0
# category                  0
# mp_name                   0
# state                     0
# district                  0
# agency_name               0
# sanction_date             0
# expected_completion       0
# actual_completion      4270
# estimated_cost            0
# sanctioned_amount         0
# released_amount           0
# expenditure               0
# progress_percentage       0
# latitude                  0
# longitude                 0
# status                    0
# is_cost_anomaly           0
# is_exp_anomaly            0
# is_progress_anomaly       0
# is_delay                  0
# is_duplicate              0
# dtype: int64

# %%
df[["progress_percentage" , 'actual_completion' , 'is_progress_anomaly']]
# Out:
#       progress_percentage actual_completion  is_progress_anomaly
# 0                   62.05               NaN                False
# 1                   47.58               NaN                False
# 2                  100.00        2024-04-17                False
# 3                   50.93               NaN                False
# 4                   42.32               NaN                False
# ...                   ...               ...                  ...
# 4995                78.82               NaN                False
# 4996                75.68               NaN                False
# 4997                47.00               NaN                False
# 4998                45.67               NaN                False
# 4999                51.12               NaN                False
#
# [5000 rows x 3 columns]

# %%
df.loc[df['actual_completion'].notna(), 'progress_percentage'] = 100

# %%
df2 = pd.read_csv("C:\TriNetra\data\mainData.csv")
df2.shape
# Out:
# (12001, 12)
